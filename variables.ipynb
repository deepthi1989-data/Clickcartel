# %%
#three level name space
catalog_name="Clickcartel"

system_schema="_system"
landing_schema="landing"
bronze_schema="bronze"
silver_schema="silver"
gold_schema="gold"

#data generator load data to below paths
raw_streaming_path=f"/Volumes/{catalog_name}/{landing_schema}/streaming/user_events"
raw_batch_customer_path=f"/Volumes/{catalog_name}/{landing_schema}/batch/customer"
raw_batch_product_path=f"/Volumes/{catalog_name}/{landing_schema}/batch/product"

#checkpointing and schemalocation
checkpoint_path=f"/Volumes/{catalog_name}/{system_schema}/checkpoints"
schema_location=f"/Volumes/{catalog_name}/{system_schema}/schemas"
